# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

max_features = 10000
max_len = 200

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

model = Sequential([
    Embedding(max_features, 128, input_length=max_len),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X_train, y_train,
          epochs=3,
          batch_size=64,
          validation_split=0.2)

loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/3
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 51s 159ms/step - accuracy: 0.7961 - loss: 0.4425 - val_accuracy: 0.8398 - val_loss: 0.3730
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 53s 168ms/step - accuracy: 0.8865 - loss: 0.2844 - val_accuracy: 0.8496 - val_loss: 0.3417
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 48s 155ms/step - accuracy: 0.9291 - loss: 0.1851 - val_accuracy: 0.8704 - val_loss: 0.3195
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8619 - loss: 0.3362
# Accuracy: 0.8619199991226196

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

text = "deep learning is amazing and powerful"

chars = sorted(list(set(text)))
char_to_idx = {c:i for i,c in enumerate(chars)}
idx_to_char = {i:c for i,c in enumerate(chars)}

seq_length = 5
X, y = [], []

for i in range(len(text)-seq_length):
    seq = text[i:i+seq_length]
    target = text[i+seq_length]

    X.append([char_to_idx[c] for c in seq])
    y.append(char_to_idx[target])

X = np.array(X)
y = np.array(y)

X = X / len(chars)

model = Sequential([
    LSTM(64, input_shape=(seq_length,1)),
    Dense(len(chars), activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam')

X = X.reshape((X.shape[0], X.shape[1], 1))
model.fit(X, y, epochs=50, batch_size=16)

print("Text generation model trained.")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8325
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8272
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8223
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.8179
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.8130
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.8099
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.8039
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.8003
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.7944
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.7890
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.7838
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7777
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.7712
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.7640
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.7563
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7494
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7415
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7306
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7232
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7134
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7057
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6965
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6882
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6824
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6770
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6719
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6743
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6718
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6702
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6691
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6677
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6658
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6651
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6629
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6619
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6608
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6607
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6591
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6583
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6586
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6585
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6570
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6565
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6559
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6549
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6546
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6536
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6529
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6530
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6515
# Text generation model trained.

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

data = np.arange(100).reshape(-1,1)

scaler = MinMaxScaler()
data = scaler.fit_transform(data)

X, y = [], []
window = 5

for i in range(len(data)-window):
    X.append(data[i:i+window])
    y.append(data[i+window])

X = np.array(X)
y = np.array(y)

model = Sequential([
    LSTM(50, input_shape=(window,1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=20)

prediction = model.predict(X[-1].reshape(1,window,1))
prediction = scaler.inverse_transform(prediction)

print("Next value:", prediction)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3646
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3007
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2491
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1990
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1565
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1207
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0874
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0587
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0363
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0207
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0084
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0099
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0123
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0105
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0080
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0063
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0056
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Next value: [[87.6416]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense

# LSTM Model
lstm_model = Sequential([
    LSTM(64, input_shape=(100,1)),
    Dense(1)
])

lstm_model.compile(optimizer='adam',
                   loss='mse')

# GRU Model
gru_model = Sequential([
    GRU(64, input_shape=(100,1)),
    Dense(1)
])

gru_model.compile(optimizer='adam',
                  loss='mse')

print("LSTM Parameters:",
      lstm_model.count_params())

print("GRU Parameters:",
      gru_model.count_params())
# Out:
# LSTM Parameters: 16961
# GRU Parameters: 12929
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
